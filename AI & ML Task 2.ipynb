# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Import Dataset from Kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jayaantanaath/student-habits-vs-academic-performance")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\aishw\.cache\kagglehub\datasets\jayaantanaath\student-habits-vs-academic-performance\versions\1

# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# # Read the Dataset

# %%
df=pd.read_csv("C:\\Users\\aishw\\.cache\\kagglehub\\datasets\\jayaantanaath\\student-habits-vs-academic-performance\\versions\\1\\student_habits_performance.csv")
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.head(10)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
# 5      S1005   24    Male                  7.2                 1.3
# 6      S1006   21  Female                  5.6                 1.5
# 7      S1007   21  Female                  4.3                 1.0
# 8      S1008   23  Female                  4.4                 2.2
# 9      S1009   18  Female                  4.8                 3.1
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# ...

# %%
df.tail(10)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 990      S1990   18    Male                  3.2                 3.5
# 991      S1991   20    Male                  6.0                 2.1
# 992      S1992   18    Male                  3.5                 0.0
# 993      S1993   20    Male                  3.8                 2.1
# 994      S1994   20  Female                  1.6                 1.3
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 990            1.7            No                   91.7          6.5
# ...

# %% [markdown]
# # Understanding the Data

# %%
df.shape  #Retrieving the number of rows and columns in the dataset
# Out:
# (1000, 16)

# %%
df.columns #Exploring the column names of the dataset
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.dtypes  #Information about each column and their datatype
# Out:
# student_id                        object
# age                                int64
# gender                            object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating               int64
# extracurricular_participation     object
# exam_score                       float64
# dtype: object

# %%
df.info()  #To get all useful information related to the Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.describe().T  #Descriptive statistics
# Out:
#                         count     mean        std   min     25%   50%     75%  \
# age                    1000.0  20.4980   2.308100  17.0  18.750  20.0  23.000
# study_hours_per_day    1000.0   3.5501   1.468890   0.0   2.600   3.5   4.500
# social_media_hours     1000.0   2.5055   1.172422   0.0   1.700   2.5   3.300
# netflix_hours          1000.0   1.8197   1.075118   0.0   1.000   1.8   2.525
# attendance_percentage  1000.0  84.1317   9.399246  56.0  78.000  84.4  91.025
# sleep_hours            1000.0   6.4701   1.226377   3.2   5.600   6.5   7.300
# exercise_frequency     1000.0   3.0420   2.025423   0.0   1.000   3.0   5.000
# mental_health_rating   1000.0   5.4380   2.847501   1.0   3.000   5.0   8.000
# exam_score             1000.0  69.6015  16.888564  18.4  58.475  70.5  81.325
#
#                          max
# age                     24.0
# study_hours_per_day      8.3
# social_media_hours       7.2
# netflix_hours            5.4
# attendance_percentage  100.0
# ...

# %% [markdown]
# # Sanity Check & Data Preparation

# %%
#Identifying the number of missing values in the dataset
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
#Percentage of missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# student_id                       0.0
# age                              0.0
# gender                           0.0
# study_hours_per_day              0.0
# social_media_hours               0.0
# netflix_hours                    0.0
# part_time_job                    0.0
# attendance_percentage            0.0
# sleep_hours                      0.0
# diet_quality                     0.0
# exercise_frequency               0.0
# parental_education_level         9.1
# internet_quality                 0.0
# mental_health_rating             0.0
# extracurricular_participation    0.0
# exam_score                       0.0
# dtype: float64

# %%
df.duplicated().sum()  #Identifying duplicate values in the Dataset
# Out:
# 0

# %%
#Find the number of unique values
df.nunique()
# Out:
# student_id                       1000
# age                                 8
# gender                              3
# study_hours_per_day                78
# social_media_hours                 60
# netflix_hours                      51
# part_time_job                       2
# attendance_percentage             320
# sleep_hours                        68
# diet_quality                        3
# exercise_frequency                  7
# parental_education_level            3
# internet_quality                    3
# mental_health_rating               10
# extracurricular_participation       2
# exam_score                        480
# dtype: int64

# %%
#Extract unique values from a column
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
#Count of each unique value in the column
df['gender'].value_counts()
# Out:
# gender
# Female    481
# Male      477
# Other      42
# Name: count, dtype: int64

# %%
df.sample(10)  #Retrieve random rows
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 498      S1498   17  Female                  2.0                 2.7
# 654      S1654   22  Female                  3.1                 4.7
# 550      S1550   17  Female                  5.2                 1.5
# 458      S1458   19    Male                  2.9                 3.0
# 843      S1843   23  Female                  3.0                 4.8
# 639      S1639   24  Female                  3.5                 2.9
# 363      S1363   18    Male                  2.1                 2.1
# 875      S1875   19  Female                  7.6                 3.0
# 515      S1515   19  Female                  3.0                 0.1
# 761      S1761   18  Female                  4.6                 3.4
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 498            2.0            No                   91.9          6.7
# ...

# %%
#Displaying all rows of a particular column that contains missing values
df.loc[df['parental_education_level'].isnull()]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 10       S1010   19  Female                  4.6                 3.7
# 33       S1033   18  Female                  4.0                 0.9
# 47       S1047   23  Female                  2.5                 2.9
# 74       S1074   21  Female                  2.3                 1.0
# 93       S1093   22    Male                  4.1                 2.5
# ..         ...  ...     ...                  ...                 ...
# 921      S1921   23  Female                  4.4                 2.7
# 925      S1925   19   Other                  1.7                 2.9
# 939      S1939   18  Female                  4.7                 3.2
# 945      S1945   23    Male                  6.0                 2.9
# 967      S1967   22    Male                  5.2                 4.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
#Filling missing value in numerical column using Mode
for i in ["parental_education_level"]:
    df[i].fillna(df[i].mode()[0],inplace=True)
# Out:
# C:\Users\aishw\AppData\Local\Temp\ipykernel_28424\2262686646.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isna().sum()  #Checking for null values after filling
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %% [markdown]
# # Analysis of Relationships between Variables
# 1. Univariate Analysis
# 2. Bivariate Analysis

# %% [markdown]
# ### Univariate Analyis - Analyzing one variable at a time

# %%
df.sample(10)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 226      S1226   21    Male                  5.5                 2.2
# 581      S1581   17    Male                  3.2                 3.1
# 28       S1028   24    Male                  4.3                 2.0
# 253      S1253   21    Male                  6.7                 1.4
# 935      S1935   17    Male                  3.4                 4.0
# 774      S1774   18  Female                  7.5                 3.6
# 575      S1575   22    Male                  1.1                 1.9
# 181      S1181   23    Male                  3.5                 3.0
# 944      S1944   21  Female                  1.7                 1.6
# 866      S1866   21  Female                  6.2                 2.7
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 226            0.9           Yes                   84.1          5.0
# ...

# %%
#Histogram to understand the distribution for numerical columns
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
#Plotting a Kernel Density Estimation (KDE) Plot
for i in df.select_dtypes(include="number").columns:
    sns.kdeplot(data=df,x=i,color="green")
    plt.show()

# %%
#Boxplot to identify outliers
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %% [markdown]
# ### Bivariate Analyis - Comparing two variables at a time

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
#Pairplot - Comparing more number of numerical variables with colour (hue) based on another variable which can be categorical
sns.pairplot(df,vars=['social_media_hours','exam_score','attendance_percentage', 'sleep_hours'],hue='mental_health_rating')
plt.show()

# %%
#Scatterplot
for i in df.select_dtypes(include="number").columns:
    sns.scatterplot(data=df,x=i,y='exam_score',hue='gender')
    plt.show()

# %%
#Correlation Matrix
s=df.select_dtypes(include="number").corr()
s
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.003971           -0.009151
# study_hours_per_day    0.003971             1.000000            0.020282
# social_media_hours    -0.009151             0.020282            1.000000
# netflix_hours         -0.001174            -0.031158            0.011477
# attendance_percentage -0.026055             0.026264            0.040479
# sleep_hours            0.037482            -0.027757            0.018236
# exercise_frequency    -0.003836            -0.028701           -0.037319
# mental_health_rating  -0.045101            -0.003768            0.001496
# exam_score            -0.008907             0.825419           -0.166733
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                        -0.001174              -0.026055     0.037482
# study_hours_per_day        -0.031158               0.026264    -0.027757
# ...

# %%
#Correlation with heatmap to interpret the relation and multicolinearity
s=df.select_dtypes(include="number").corr()
plt.figure(figsize=(15,15))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature Engineering

# %%
#Adding a grade column to the DataFrame based on the exam_score column
#Building a function to assign appropriate grades to the marks 
def assign_grades(exam_score):
    if(exam_score>=90 and exam_score<=100):
        return "O (Outstanding)"
    elif(exam_score>=80 and exam_score<90):
        return "D+ (Excellent)"
    elif(exam_score>=75 and exam_score<80):
        return "D (Distinction)"
    elif(exam_score>=70 and exam_score<75):
        return "A+ (Very Good)"
    elif(exam_score>=60 and exam_score<70):
        return "A (Good)"
    elif(exam_score>=50 and exam_score<60):
        return "B (Average)"
    else:
        return "U (Re-Appear)"

#Applying the function
df['grade']=df['exam_score'].apply(assign_grades)

# %%
#Checking the DataFrame for the newly added columns
df.sample(15)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 296      S1296   22  Female                  4.6                 1.8
# 51       S1051   22  Female                  2.5                 3.2
# 879      S1879   21  Female                  0.8                 2.3
# 365      S1365   23  Female                  5.1                 3.1
# 854      S1854   23  Female                  4.7                 1.8
# 607      S1607   24  Female                  3.2                 3.0
# 207      S1207   20  Female                  2.1                 0.5
# 519      S1519   18    Male                  2.9                 2.2
# 377      S1377   17  Female                  2.7                 3.6
# 11       S1011   23    Male                  3.9                 2.4
# 32       S1032   20   Other                  2.6                 4.9
# 564      S1564   20    Male                  2.1                 4.9
# 728      S1728   21   Other                  2.8                 2.0
# ...

# %% [markdown]
# # Drawing inferences by asking questions from the data
# 1. How does the time spent on social media and Netflix affect the sleep and mental health of a student ?
# 2. How many students are working part-time based on gender ?
# 3. What is the optimal study hours followed by toppers ?
# 4. Does diet have any impact on the exam scores of a student ?

# %%
#1. How does the time spent on social media and Netflix affect the sleep and mental health of a student ?
#Answering the 1st question using a Relational plot (Scatter plot)
ax=sns.relplot(data=df,x=df['social_media_hours']+df['netflix_hours'],y='sleep_hours',hue='mental_health_rating')
ax.set_axis_labels('Total Screen Time','Sleep Hours')
plt.title("Impact of Screen Time on Sleep and Mental Health")
plt.show()

# %%
#2.  How many students are working part-time based on gender ?
#Answering the 2nd question using a Bar Plot
df[df["part_time_job"] == "Yes"]["gender"].value_counts() \
            .plot(kind='bar',xlabel='Gender',ylabel='No. of Students',color=["lightblue","pink","lavender"])
plt.title("Count of Students working Part-time based on Gender")
plt.show()

# %%
#3. What is the optimal study hours followed by toppers ?
#Answering the 3rd question using a Relational plot (Scatter plot)
toppers=df[df['exam_score']>=90]
toppers
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 1        S1001   20  Female                  6.9                 2.8
# 5        S1005   24    Male                  7.2                 1.3
# 9        S1009   18  Female                  4.8                 3.1
# 22       S1022   18   Other                  4.9                 2.3
# 49       S1049   22  Female                  6.1                 2.5
# ..         ...  ...     ...                  ...                 ...
# 945      S1945   23    Male                  6.0                 2.9
# 951      S1951   20  Female                  3.3                 2.2
# 960      S1960   17    Male                  7.1                 1.9
# 972      S1972   17  Female                  4.5                 0.4
# 977      S1977   24  Female                  5.8                 1.3
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.relplot(data=toppers,x='exam_score',y='study_hours_per_day')
plt.title("Optimal Study Hours of Toppers")
plt.show()

# %%
#4. Does diet have any impact on the exam scores of a students ?
#Answering the 4th question using a horizontal bar plot
df.groupby('diet_quality')['exam_score'].mean() \
        .plot(kind='barh',xlabel="Exam Scores",ylabel="Diet Quality",color=["navy","slateblue","cyan"])
plt.title("Average of scores based on Diet Quality")
plt.show()

# %%
df.to_csv('Students_Dataset_Updated.csv',index=False)
